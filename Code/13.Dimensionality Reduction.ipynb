# %% [markdown]
# ### Dimensionality Reduction
#
# #### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.manifold import TSNE

# %% [markdown]
# #### Data

# %%
df = pd.read_csv('../Data/Digits.csv')
df.head()
# Out:
#    P0  P1  P2  P3  P4  P5  P6  P7  P8  P9  ...  P55  P56  P57  P58  P59  P60  \
# 0   0   0   5  14   4   0   0   0   0   0  ...    0    0    0    4   12   14
# 1   0   0   0   3  16  11   1   0   0   0  ...    0    0    0    0    2   14
# 2   0   0   7  11  11   6   0   0   0   9  ...    0    0    0   14   16   12
# 3   0   0   9  13   1   0   0   0   0   0  ...    5    0    0    4   15   16
# 4   0   0   0  10  12   0   0   0   0   0  ...    0    0    0    1   11   14
#
#    P61  P62  P63  y
# 0    7    0    0  6
# 1   14    1    0  1
# 2   10    1    0  3
# 3   16   16   16  1
# 4   12    1    0  6
#
# [5 rows x 65 columns]

# %%
X = df.drop('y', axis=1).values
y = df['y'].values

# %% [markdown]
# **Split** the Data Set into Train Set and Test Set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=0)

# %% [markdown]
# ### Principal Component Analysis

# %%
pca = PCA()
pca.fit(X_train, y_train)
X_transform = pca.transform(X_train)
plt.plot(pca.explained_variance_ratio_);

# %%
sns.scatterplot(x = X_transform[:, 0], 
                y = X_transform[:, 1], 
                style = y_train, 
                hue = y_train, 
                palette = ['r','g','b']);

# %%
print(f'Train Accuracy : {pca.score(X_train, y_train):.2f}')
# Out:
# Train Accuracy : 185.05

# %%
X_transform = pca.transform(X_test)
sns.scatterplot(x = X_transform[:, 0], 
                y = X_transform[:, 1], 
                style = y_test, 
                hue = y_test, 
                palette=['r','g','b']);

# %%
print(f'Test Accuracy : {pca.score(X_test, y_test):.2f}')
# Out:
# Test Accuracy : 185.75

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=0)

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
X_transform = lda.transform(X_train)

# %%
sns.scatterplot(x = X_transform[:, 0], 
                y = X_transform[:, 1], 
                style = y_train, 
                hue = y_train, 
                palette = ['r','g','b']);

# %%
print(f'Train Accuracy : {lda.score(X_train, y_train)*100:.2f}%')
# Out:
# Train Accuracy : 99.57%

# %%
X_transform = lda.transform(X_test)
sns.scatterplot(x = X_transform[:, 0], 
                y = X_transform[:, 1], 
                style = y_test, 
                hue = y_test, 
                palette=['r','g','b']);

# %%
print(f'Test Accuracy : {lda.score(X_test, y_test)*100:.2f}%')
# Out:
# Test Accuracy : 99.57%

# %% [markdown]
# ### TSNE : t Distributed Stochastic Neighbor Embedding

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
tsne.get_params()
# Out:
# {'angle': 0.5,
#  'early_exaggeration': 12.0,
#  'init': 'random',
#  'learning_rate': 200.0,
#  'method': 'barnes_hut',
#  'metric': 'euclidean',
#  'min_grad_norm': 1e-07,
#  'n_components': 2,
#  'n_iter': 1000,
#  'n_iter_without_progress': 300,
#  'n_jobs': None,
#  'perplexity': 30.0,
#  'random_state': 0,
#  'square_distances': 'legacy',
#  'verbose': 0}

# %% [markdown]
# ### Perplexity = 1
#
# How it Combines the High Dimensionality Data down to 2 Dimensionality

# %%
tsne = TSNE(n_components=2, 
            perplexity=1, 
            random_state=0)

X_transform = tsne.fit_transform(X)

sns.scatterplot(x = X_transform[:,0], 
                y = X_transform[:, 1], 
                style = y, 
                hue = y, 
                palette = ['r','g','b']);

# %% [markdown]
# ### Perplexity = 2

# %%
tsne = TSNE(n_components=2, 
            perplexity=2, 
            random_state=0)

X_transform = tsne.fit_transform(X)

sns.scatterplot(x = X_transform[:,0], 
                y = X_transform[:, 1], 
                style = y, 
                hue = y, 
                palette = ['r','g','b']);

# %% [markdown]
# ### Perplexity = 5

# %%
tsne = TSNE(n_components=2, 
            perplexity=5, 
            random_state=0)

X_transform = tsne.fit_transform(X)

sns.scatterplot(x = X_transform[:,0], 
                y = X_transform[:, 1], 
                style = y, 
                hue = y, 
                palette = ['r','g','b']);

# %% [markdown]
# ### Perplexity = 10

# %%
tsne = TSNE(n_components=2, 
            perplexity=10, 
            random_state=0)

X_transform = tsne.fit_transform(X)

sns.scatterplot(x = X_transform[:,0], 
                y = X_transform[:, 1], 
                style = y, 
                hue = y, 
                palette = ['r','g','b']);

# %% [markdown]
# ### Perplexity = 50

# %%
tsne = TSNE(n_components=2, 
            perplexity=50, 
            random_state=0)

X_transform = tsne.fit_transform(X)

sns.scatterplot(x = X_transform[:,0], 
                y = X_transform[:, 1], 
                style = y, 
                hue = y, 
                palette = ['r','g','b']);
